# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargav-joshi/NLP-Practicals/blob/main/NLP_Exp1_Text_Pre_processing_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Remove HTML tags

import requests
URL = "https://vit.edu.in/"
page = requests.get(URL)
data = page.text
print(data)
# Out:
# ï»¿<!DOCTYPE html>
# <html lang="en">
#    <head>
#       <meta charset="UTF-8">
#       <meta http-equiv="content-type" content="text/html;charset=utf-8" />
#       <meta name="viewport" content="width=device-width, initial-scale=1.0">
#       <meta http-equiv="X-UA-Compatible" content="ie=edge">
#       <title>VIT</title>
#       <link rel="apple-touch-icon" sizes="180x180" href="images/favicon.png">
#       <link rel="icon" type="image/png" sizes="32x32" href="images/favicon.png">
#       <link rel="icon" type="image/png" sizes="16x16" href="images/favicon.png">
#       <!-- plugin scripts -->
#       <link href="https://fonts.googleapis.com/css2?family=Source+Sans+Pro:ital,wght@0,200;0,300;0,400;0,600;0,700;0,900;1,200;1,300;1,400;1,600;1,700;1,900&display=swap" rel="stylesheet">
#       <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
#       <link rel="stylesheet" href="css/animate.min.css">
# ...

# %%
data = "While he [Mr. Smith] was writing his book, Magic: the little known world! he stated, “I always… wanted to ask a magician, ‘How do you do it?’”; he luckily got the chance while he was living above a math-based magic shop (where he lived from 1993 — 1997) called 2{1+[23-3]}=x. He used to write his book sitting in café having his latté as he didn't like tea."

# %%
# Removing HTML tags
from bs4 import BeautifulSoup
def remove_html(text):
    return BeautifulSoup(text, "lxml").text
print(remove_html(data))
# Out:
# While he [Mr. Smith] was writing his book, Magic: the little known world! he stated, “I always… wanted to ask a magician, ‘How do you do it?’”; he luckily got the chance while he was living above a math-based magic shop (where he lived from 1993 — 1997) called 2{1+[23-3]}=x. He used to write his book sitting in café having his latté as he didn't like tea.

# %%
def remove_whitespace(text):
    return  " ".join(text.split())
remove_whitespace(data)
# Out:
# "While he [Mr. Smith] was writing his book, Magic: the little known world! he stated, “I always… wanted to ask a magician, ‘How do you do it?’”; he luckily got the chance while he was living above a math-based magic shop (where he lived from 1993 — 1997) called 2{1+[23-3]}=x. He used to write his book sitting in café having his latté as he didn't like tea."

# %%
# !pip install unidecode
# Out:
# ...
#      |████████████████████████████████| 235 kB 7.6 MB/s
# ...

# %%
#Convert accented characters
import unidecode
def remove_accented_chars(text):
    text = unidecode.unidecode(text)
    return text

# %%
#	Expand contractions
def expand_contractions(text):
    text = contractions.fix(text)
    return text

# %%
#Remove special characters
s=""
for character in data:
    if character==" " or character.isalnum():
        s+=character
print(s)
# Out:
# While he Mr Smith was writing his book Magic the little known world he stated I always wanted to ask a magician How do you do it he luckily got the chance while he was living above a mathbased magic shop where he lived from 1993  1997 called 21233x He used to write his book sitting in café having his latté as he didnt like tea

# %%
#Lowercase all text
print(s.lower())
# Out:
# while he mr smith was writing his book magic the little known world he stated i always wanted to ask a magician how do you do it he luckily got the chance while he was living above a mathbased magic shop where he lived from 1993  1997 called 21233x he used to write his book sitting in café having his latté as he didnt like tea

# %%
#Remove numbers

result = ''.join([i for i in s if not i.isdigit()])
print(result)
# Out:
# While he Mr Smith was writing his book Magic the little known world he stated I always wanted to ask a magician How do you do it he luckily got the chance while he was living above a mathbased magic shop where he lived from    called x He used to write his book sitting in café having his latté as he didnt like tea

# %%
# !pip install nltk

# %%
#Remove stopwords
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
def remove_stopwords(result):
  return " ".join([word for word in str(s).split() if word not in stop_words])
print(remove_stopwords(result))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# While Mr Smith writing book Magic little known world stated I always wanted ask magician How luckily got chance living mathbased magic shop lived 1993 1997 called 21233x He used write book sitting café latté didnt like tea

# %%
z = " ".join([word for word in str(result).split() if word not in stop_words])
print(result)
# Out:
# While he Mr Smith was writing his book Magic the little known world he stated I always wanted to ask a magician How do you do it he luckily got the chance while he was living above a mathbased magic shop where he lived from    called x He used to write his book sitting in café having his latté as he didnt like tea

# %%
#3Stemming
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
def stem_words(resultv):
    return " ".join([stemmer.stem(word) for word in result.split()])
stem_words(result)
# Out:
# 'while he Mr smith wa write hi book magic the littl known world he state I alway want to ask a magician how do you do it he luckili got the chanc while he wa live abov a mathbas magic shop where he live from call x He use to write hi book sit in café have hi latté as he didnt like tea'

# %%
#Lemmatization
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
def lemmatize_words(result):
    return " ".join([lemmatizer.lemmatize(word) for word in result.split()])
lemmatize_words(result)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 'While he Mr Smith wa writing his book Magic the little known world he stated I always wanted to ask a magician How do you do it he luckily got the chance while he wa living above a mathbased magic shop where he lived from called x He used to write his book sitting in café having his latté a he didnt like tea'

# %%
data2 = " John goes to school everyday. He is a brilliant Student. He likes the subject Maths"

# %%
#Tokenizing sentences
nltk.download('punkt')

from nltk.tokenize import sent_tokenize
print(sent_tokenize(data2))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [' John goes to school everyday.', 'He is a brilliant Student.', 'He likes the subject Maths']

# %%
#Tokenize words
from nltk import word_tokenize
print(word_tokenize(data2))
# Out:
# ['John', 'goes', 'to', 'school', 'everyday', '.', 'He', 'is', 'a', 'brilliant', 'Student', '.', 'He', 'likes', 'the', 'subject', 'Maths']
